# %% [markdown]
# # Marketing Campaign Dataset

# %%
import pandas as pd
import numpy as np

# %%
pdata = pd.read_csv("project_data.csv")
pdata
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
pdata.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     2/10/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %%
edata = pd.read_csv("edu_data.csv")
edata
# Out:
#   educational_level educational_status_code
# 0        Graduation                      GD
# 1               PhD                      PH
# 2            Master                      MS
# 3             Basic                      BS
# 4       High School                      HS

# %%
data1 = pd.read_excel("customer_data.xlsx", sheet_name="Data 1")
data2 = pd.read_excel("customer_data.xlsx", sheet_name="Data 2")

# %%
data1
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 0    20201733           1940                      GD        Married
# 1    20202059           1943                     NaN        Married
# 2    20202195           1944                      PH       Divorced
# 3    20201983           1946                      GD   Relationship
# 4    20202060           1948                      PH       Divorced
# ..        ...            ...                     ...            ...
# 106  20201737           1970                      PH        Married
# 107  20201970           1970                      GD        Widowed
# 108  20201707           1971                      GD       Divorced
# 109  20201994           1971                      GD         Single
# 110  20202034           1971                     NaN   Relationship
#
#      annual_income              full_name
# 0          40548.0            Abhinav Bal
# 1          65073.0            Nimai Neela
# ...

# %%
data1.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                     NaN        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0        40548.0            Abhinav Bal
# 1        65073.0            Nimai Neela
# 2        55614.0         Somatra Savant
# 3        46276.0            Kamana Nath
# 4        46681.0  Ninarika Chandrasekar

# %%
data2
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 0    20202049           1971                      GD       Divorced
# 1    20202198           1971                      PH   Relationship
# 2    20202038           1972                      GD         Single
# 3    20202177           1972                      PH         Single
# 4    20202182           1972                      MS       Divorced
# ..        ...            ...                     ...            ...
# 275  20201886           2000                      GD         Single
# 276  20202023           2000                      PH   Relationship
# 277  20202089           2000                      GD   Relationship
# 278  20202119           2000                      GD         Single
# 279  20202153           2000                      MS         Single
#
#      annual_income         full_name
# 0          30372.0        Navya Vish
# 1          43624.0     Souvik Saxena
# ...

# %%
data2.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20202049           1971                      GD       Divorced
# 1  20202198           1971                      PH   Relationship
# 2  20202038           1972                      GD         Single
# 3  20202177           1972                      PH         Single
# 4  20202182           1972                      MS       Divorced
#
#    annual_income         full_name
# 0        30372.0        Navya Vish
# 1        43624.0     Souvik Saxena
# 2        30675.0       Naras Uddin
# 3        41644.0  Reyansh Sankaran
# 4        37760.0       Taia Sharma

# %%
# concatenating data1 and data2
data=pd.concat([data1,data2])
data
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 0    20201733           1940                      GD        Married
# 1    20202059           1943                     NaN        Married
# 2    20202195           1944                      PH       Divorced
# 3    20201983           1946                      GD   Relationship
# 4    20202060           1948                      PH       Divorced
# ..        ...            ...                     ...            ...
# 275  20201886           2000                      GD         Single
# 276  20202023           2000                      PH   Relationship
# 277  20202089           2000                      GD   Relationship
# 278  20202119           2000                      GD         Single
# 279  20202153           2000                      MS         Single
#
#      annual_income              full_name
# 0          40548.0            Abhinav Bal
# 1          65073.0            Nimai Neela
# ...

# %%
# getting top 5 records
data.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                     NaN        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0        40548.0            Abhinav Bal
# 1        65073.0            Nimai Neela
# 2        55614.0         Somatra Savant
# 3        46276.0            Kamana Nath
# 4        46681.0  Ninarika Chandrasekar

# %%
# giving all the information about the dataset
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        499 non-null    int64
#  1   year_of_birth      499 non-null    int64
#  2   educational_level  499 non-null    object
#  3   marital_status     499 non-null    object
#  4   annual_income      486 non-null    float64
#  5   purhcase_date      499 non-null    object
#  6   recency            499 non-null    int64
#  7   online_purchases   499 non-null    int64
#  8   store_purchases    499 non-null    int64
#  9   complaints         499 non-null    int64
#  10  calls              499 non-null    int64
#  11  intercoms          499 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 46.9+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 391 entries, 0 to 279
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cust_id                  391 non-null    int64
#  1   year_of_birth            391 non-null    int64
#  2   educational_status_code  363 non-null    object
#  3   marital_status           391 non-null    object
#  4   annual_income            373 non-null    float64
#  5   full_name                391 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 21.4+ KB

# %%
data['educational_status_code'].value_counts()
# Out:
# GD    195
# PH     80
# MS     54
# HS     28
# BS      6
# Name: educational_status_code, dtype: int64

# %%
# filling all the null values in 'educational_status_code' with the mode of the column

data['educational_status_code'].fillna(data['educational_status_code'].mode()[0],inplace=True)

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# annual_income              18
# cust_id                     0
# year_of_birth               0
# educational_status_code     0
# marital_status              0
# full_name                   0
# dtype: int64

# %%
# filling all the null values in 'annual_income' with the mean of the column 

data['annual_income'].fillna(data['annual_income'].mean(),inplace=True)
data.isna().sum().sort_values(ascending=False)
# Out:
# cust_id                    0
# year_of_birth              0
# educational_status_code    0
# marital_status             0
# annual_income              0
# full_name                  0
# dtype: int64

# %%
edata.isna().sum().sort_values(ascending=False)
# Out:
# educational_level          0
# educational_status_code    0
# dtype: int64

# %%
pdata.isna().sum().sort_values(ascending=False)
# Out:
# annual_income        13
# customer_id           0
# year_of_birth         0
# educational_level     0
# marital_status        0
# purhcase_date         0
# recency               0
# online_purchases      0
# store_purchases       0
# complaints            0
# calls                 0
# intercoms             0
# dtype: int64

# %%
pdata['annual_income'].fillna(pdata['annual_income'].mean(),inplace=True)
pdata.isna().sum().sort_values(ascending=False)
# Out:
# customer_id          0
# year_of_birth        0
# educational_level    0
# marital_status       0
# annual_income        0
# purhcase_date        0
# recency              0
# online_purchases     0
# store_purchases      0
# complaints           0
# calls                0
# intercoms            0
# dtype: int64

# %%
data.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                      GD        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0        40548.0            Abhinav Bal
# 1        65073.0            Nimai Neela
# 2        55614.0         Somatra Savant
# 3        46276.0            Kamana Nath
# 4        46681.0  Ninarika Chandrasekar

# %%
# giving all the datatypes of the columns

data.dtypes
# Out:
# cust_id                      int64
# year_of_birth                int64
# educational_status_code     object
# marital_status              object
# annual_income              float64
# full_name                   object
# dtype: object

# %%
cat_cols=data.select_dtypes(include='object').columns.tolist()[0:-1]

# %%
for i in cat_cols:
    print(data[i].value_counts())
    print()
# Out:
# GD    223
# PH     80
# MS     54
# HS     28
# BS      6
# Name: educational_status_code, dtype: int64
#
# Married         94
# Relationship    91
# Single          84
# Divorced        71
# Widowed         45
# Widow            6
# Name: marital_status, dtype: int64

# %%
data['marital_status']=data['marital_status'].replace('Widow','Widowed')

# %%
for i in cat_cols:
    print(data[i].value_counts())
    print()
# Out:
# GD    223
# PH     80
# MS     54
# HS     28
# BS      6
# Name: educational_status_code, dtype: int64
#
# Married         94
# Relationship    91
# Single          84
# Divorced        71
# Widowed         51
# Name: marital_status, dtype: int64

# %%
data.groupby(by=['marital_status'])[['annual_income']].mean().sort_values(by=['annual_income'],ascending=False).reset_index()
# Out:
#   marital_status  annual_income
# 0         Single   53151.664241
# 1        Widowed   52524.568627
# 2       Divorced   50690.997848
# 3   Relationship   50642.414224
# 4        Married   49303.624950

# %%
# joining 2 datasets

df=pd.merge(pdata,data,how='inner',left_on='customer_id',right_on='cust_id')
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status_x  \
# 0       20201701            1982        Graduation           Single
# 1       20201702            1950        Graduation          Married
# 2       20201703            1965        Graduation         Divorced
# 3       20201705            1981               PhD          Widowed
# 4       20201706            1967            Master     Relationship
# ..           ...             ...               ...              ...
# 386     20202195            1944               PhD         Divorced
# 387     20202196            1962            Master         Divorced
# 388     20202197            1978        Graduation         Divorced
# 389     20202198            1971               PhD     Relationship
# 390     20202199            1949               PhD     Relationship
#
#      annual_income_x purhcase_date  recency  online_purchases  \
# 0            58138.0      9/4/2012       58                 8
# ...

# %%
df.drop(['cust_id','marital_status_y','annual_income_y'],axis=1,inplace=True)

# %%
df.drop(['year_of_birth'],axis=1,inplace=True)

# %%
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status_x  \
# 0       20201701            1982        Graduation           Single
# 1       20201702            1950        Graduation          Married
# 2       20201703            1965        Graduation         Divorced
# 3       20201705            1981               PhD          Widowed
# 4       20201706            1967            Master     Relationship
# ..           ...             ...               ...              ...
# 386     20202195            1944               PhD         Divorced
# 387     20202196            1962            Master         Divorced
# 388     20202197            1978        Graduation         Divorced
# 389     20202198            1971               PhD     Relationship
# 390     20202199            1949               PhD     Relationship
#
#      annual_income_x purhcase_date  recency  online_purchases  \
# 0            58138.0      9/4/2012       58                 8
# ...

# %%
df.columns=['customer_id', 'year_of_birth', 'educational_level',
       'marital_status', 'annual_income', 'purhcase_date', 'recency',
       'online_purchases', 'store_purchases', 'complaints', 'calls',
       'intercoms', 'educational_status_code', 'full_name']

# %%
df
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 0       20201701           1982        Graduation         Single
# 1       20201702           1950        Graduation        Married
# 2       20201703           1965        Graduation       Divorced
# 3       20201705           1981               PhD        Widowed
# 4       20201706           1967            Master   Relationship
# ..           ...            ...               ...            ...
# 386     20202195           1944               PhD       Divorced
# 387     20202196           1962            Master       Divorced
# 388     20202197           1978        Graduation       Divorced
# 389     20202198           1971               PhD   Relationship
# 390     20202199           1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
df.isna().sum()
# Out:
# customer_id                0
# year_of_birth              0
# educational_level          0
# marital_status             0
# annual_income              0
# purhcase_date              0
# recency                    0
# online_purchases           0
# store_purchases            0
# complaints                 0
# calls                      0
# intercoms                  0
# educational_status_code    0
# full_name                  0
# dtype: int64

# %%
df.head()
# Out:
#    customer_id  year_of_birth educational_level marital_status  annual_income  \
# 0     20201701           1982        Graduation         Single        58138.0
# 1     20201702           1950        Graduation        Married        46344.0
# 2     20201703           1965        Graduation       Divorced        71613.0
# 3     20201705           1981               PhD        Widowed        58293.0
# 4     20201706           1967            Master   Relationship        62000.0
#
#   purhcase_date  recency  online_purchases  store_purchases  complaints  \
# 0      9/4/2012       58                 8                4           0
# 1      3/8/2014       38                 1                2           0
# 2     8/21/2013       26                 8               10           0
# 3     1/19/2014       94                 5                6           0
# 4      9/9/2013       16                 6               10           5
#
# ...

# %%
# Filtering out all the data for the customers who have done 'Masters
df[df['educational_level']=='Master']
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 4       20201706           1967            Master   Relationship
# 10      20201714           1952            Master         Single
# 15      20201719           1980            Master         Single
# 26      20201731           1989            Master       Divorced
# 29      20201735           1975            Master        Married
# ..           ...            ...               ...            ...
# 377     20202181           1973            Master        Married
# 378     20202182           1972            Master       Divorced
# 380     20202187           1976            Master   Relationship
# 385     20202194           1964            Master         Single
# 387     20202196           1962            Master       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 4          62000.0      9/9/2013       16                 6               10
# ...

# %%
# Filtering out all the data for the customers who have done 'Masters and born after 1981

temp=df[(df['year_of_birth']>1981) & (df['educational_level']=='Master')]
temp
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 26      20201731           1989            Master       Divorced
# 49      20201761           1982            Master         Single
# 56      20201771           1987            Master         Single
# 61      20201777           1993            Master        Married
# 76      20201794           1982            Master         Single
# 114     20201841           1987            Master         Single
# 120     20201850           1996            Master         Single
# 146     20201884           1998            Master   Relationship
# 153     20201897           1982            Master       Divorced
# 162     20201906           1991            Master   Relationship
# 172     20201918           1985            Master        Widowed
# 173     20201919           1986            Master         Single
# 194     20201950           1994            Master        Married
# ...

# %%
# sort the above values in decreasing order of annual income and give top 10 records
temp=temp.sort_values(by=['annual_income'],ascending=False).head(10)
temp
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 114     20201841           1987            Master         Single
# 172     20201918           1985            Master        Widowed
# 342     20202136           1983            Master   Relationship
# 49      20201761           1982            Master         Single
# 61      20201777           1993            Master        Married
# 242     20202014           1991            Master        Married
# 153     20201897           1982            Master       Divorced
# 56      20201771           1987            Master         Single
# 194     20201950           1994            Master        Married
# 237     20202009           1986            Master        Married
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 114        92859.0    10/19/2012       46                 5               12
# 172        83790.0    11/15/2013       81                 8                6
# ...

# %%
temp['marital_status'].value_counts()
# Out:
# Married         4
# Single          3
# Widowed         1
# Relationship    1
# Divorced        1
# Name: marital_status, dtype: int64

# %% [raw]
# hence from this we can get insights that the person if single and born after 1981 and the education level is 'Masters' will have annual income on higher side

# %%
import datetime as dt

# %%
from datetime import date

# %%
dt.date.today()
# Out:
# datetime.date(2023, 6, 19)

# %%
# Find the age of customers based on the current year

today=dt.date.today()
year=today.year
df['age']=year-df['year_of_birth']

# %%
df
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 0       20201701           1982        Graduation         Single
# 1       20201702           1950        Graduation        Married
# 2       20201703           1965        Graduation       Divorced
# 3       20201705           1981               PhD        Widowed
# 4       20201706           1967            Master   Relationship
# ..           ...            ...               ...            ...
# 386     20202195           1944               PhD       Divorced
# 387     20202196           1962            Master       Divorced
# 388     20202197           1978        Graduation       Divorced
# 389     20202198           1971               PhD   Relationship
# 390     20202199           1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
df['total_purchases']=df['online_purchases']+df['store_purchases']

# %%
df.sort_values(by=['total_purchases'],ascending=False)
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 323     20202113           1994               PhD        Widowed
# 174     20201920           1987        Graduation         Single
# 340     20202134           1981        Graduation        Married
# 178     20201925           1992        Graduation        Widowed
# 150     20201892           1982               PhD        Married
# ..           ...            ...               ...            ...
# 1       20201702           1950        Graduation        Married
# 285     20202073           1984            Master        Married
# 295     20202085           1996            Master        Widowed
# 162     20201906           1991            Master   Relationship
# 18      20201722           1979        Graduation   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 323        66465.0     3/30/2013        1                11               12
# ...

# %% [raw]
# High Income: Above 80000
#
# Medium Income: 40000 to 79999
#
# Low Income: Below 40000
#
# 1. Create a new column called Customer class and fill it based on the above conditions.
#
# 2. Find out the average income of each customer class.

# %%
def income_grp(a):
    if a>=80000:
        return 'High Income'
    elif a>=40000:
        return 'Medium Income'
    else:
        return 'Low Income'

# %%
df['customer_class']=df['annual_income'].apply(income_grp)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.groupby(by=['customer_class']).mean()[['annual_income']].sort_values(by=['annual_income'],ascending=False)
# Out:
#                 annual_income
# customer_class
# High Income      85732.527778
# Medium Income    59043.253553
# Low Income       27731.576923

# %%
df['customer_class'].value_counts()
# Out:
# Medium Income    225
# Low Income       130
# High Income       36
# Name: customer_class, dtype: int64
